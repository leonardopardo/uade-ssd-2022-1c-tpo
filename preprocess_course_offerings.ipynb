# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ## Pre-procesamiento de archivos .accdb para el ETL
#
# #### TODO: esto produce el archivo, pero incluye también algo de exploración. Después agrego un script ejecutable que haga el mismo proceso y reciba los argumentos por línea de comandos (habría que ver si el integration services permite ejecutar un comando por consola, de esa manera se puede incluir el script dentro de la task y no haría falta correrlo a mano).

# %%
import pandas as pd
import pyodbc

# %%
# asegurarse de que tanto python como Office sean ambos 64-bit o ambos 32-bit
DRIVER = r'{Microsoft Access Driver (*.mdb, *.accdb)}'
ACCDB_PATH = r'C:\Users\Nico\uade-ssd-2022-1c-tpo\sources\course offerings.accdb'
OUTPUT_PATH = r'C:\Users\Nico\uade-ssd-2022-1c-tpo\destinations\course_offerings.csv'  # ¿creen que va en esta carpeta?

# %%
cxn = pyodbc.connect(f'Driver={DRIVER};DBQ={ACCDB_PATH};')
cursor = cxn.cursor()

# %%
from collections import OrderedDict

# referencia de días a códigos 
weekday_code_map = OrderedDict(
Monday='M',
Tuesday='T',
Wednesday='W',
Thursday='R',
Friday='F'
)

# order cronológico en hemisferio Norte (invierno empieza el 21 de Diciembre)
ordered_seasons = ['winter', 'spring', 'summer', 'fall']

# %%
# asumimos que los nombres de tablas van a seguir respetando el formato '<temporada> <AAAA>'.
def _keep_table(table_name, seasons=ordered_seasons, min_y=2000, max_y=2099):
    s_y = table_name.split()
    return (len(s_y) == 2) and (s_y[0].lower() in seasons) and s_y[1].isnumeric() and (min_y <= int(s_y[1]) <= max_y)

# obtener el nombre de las tablas
tables = [t.table_name for t in cursor.tables(tableType='TABLE') if _keep_table(t.table_name)]
tables
# Out:
# ['Fall 2019',
#  'Fall 2020',
#  'Fall 2021',
#  'Spring 2019',
#  'Spring 2020',
#  'Summer 2019',
#  'Summer 2020']

# %%
# crear un dataframe que unifique los datos de ofertas de cursos, agregue temporada y 
# transforme la columna de días en 6 columnas del tipo booleano y la de datetime a time
dfs = list()
for t in tables:
    df = pd.read_sql(f'select * from "{t}"', cxn)
    
    # Separar temporada y año, agregar una columna para ordenar cronológicamente temporadas
    season, year = t.split()
    df['Season'] = season
    df['Season Order'] = ordered_seasons.index(season.lower()) + 1
    df['Year'] = int(year)
    
    # Aplanar la columna 'Days'
    for weekday, code in weekday_code_map.items():
        df[weekday] = df['Days'].apply(lambda x: code in x.strip().split(','))
    del df['Days']
    
    # Convertir el Datetime inferido a hora
    df['Hours'] = df['Hours'].dt.strftime("%H:%M:%S")

    # agregar el dataframe a una lista para luego concatenarlos (normalizar nombre de la primer columna)
    dfs.append(df.rename(columns={df.columns[0]: 'Course'}))
    
db = pd.concat(dfs)
db
# Out:
#                Course              Course Title     Hours   Instructor  \
# 0   MIS 2113/3113-001       Comp Based Info Sys  07:30:00  Cappabianco
# 1   MIS 2113/3113-002       Comp Based Info Sys  07:30:00     Southern
# 2   MIS 2113/3113-003       Comp Based Info Sys  11:30:00     Ratwatte
# 3   MIS 2113/3113-004       Comp Based Info Sys  12:30:00        Berry
# 4   MIS 2113/3113-005       Comp Based Info Sys  13:30:00     Ratwatte
# 5   MIS 2113/3113-006       Comp Based Info Sys  09:00:00     Ferguson
# 6   MIS 2113/3113-007       Comp Based Info Sys  10:30:00       Fraley
# 7   MIS 2113/3113-008       Comp Based Info Sys  12:00:00         Crew
# 8   MIS 2113/3113-009       Comp Based Info Sys  13:30:00     Ferguson
# 9   MIS 2113/3113-010       Comp Based Info Sys  12:00:00       Fraley
# 10  MIS 2113/3113-900       Comp Based Info Sys  16:30:00     Mokrenko
# 11  MIS 2113/3113-901       Comp Based Info Sys  18:30:00       Garcia
# 12  MIS 2113/3113-902       Comp Based Info Sys  18:30:00     Benanzer
# 13  MIS 2113/3113-903       Comp Based Info Sys  18:30:00       Parker
# 14  MIS 2113/3113-904       Comp Based Info Sys  18:30:00       Parker
# 15  MIS 2113/3113-905       Comp Based Info Sys  16:30:00     Ferguson
# 16       MIS 3013-001             C Programming  09:00:00       Warner
# 17       MIS 3013-002             C Programming  10:30:00          Wun
# 18       MIS 3013-003             C Programming  12:00:00       Warner
# 19       MIS 3013-900             C Programming  18:30:00    Narayanan
# 20       MIS 3013-901             C Programming  18:30:00    Cornelius
# 21       MIS 3013-902             C Programming  18:30:00          See
# 22       MIS 3023-900           Intensive COBOL  18:30:00        Black
# 23       MIS 3033-001          JAVA Programming  09:30:00    Gruenwald
# 24       MIS 3033-002          JAVA Programming  10:30:00       Steele
# 25       MIS 3033-003              Visual Basic  10:30:00     Ratwatte
# 26       MIS 3033-004              Visual Basic  13:30:00     Ratwatte
# 27       MIS 3033-900           C++ Programming  18:30:00          See
# 28       MIS 3033-901          JAVA Programming  18:30:00          See
# 29       MIS 3353-001                 Databases  09:00:00        Carte
# ..                ...                       ...       ...          ...
# 47       MIS 5003-930      Sem-Mgt Info Systems  18:30:00       Sharma
# 48       MIS 5203-900         Sys Arch & Design  18:30:00  Schwarzkopf
# 49       MIS 5323-900        Project Management  18:30:00        Shaft
# 50       MIS 5403-900     IT Enabled E-Business  18:30:00         Zmud
# 51       MIS 6743-001    Computer Mediated Comm  12:00:00  Chidambaram
# 0        MIS 2113-001       Comp Based Info Sys  09:20:00     Ferguson
# 1        MIS 2113-002       Comp Based Info Sys  10:30:00     Ferguson
# 2        MIS 2113-003       Comp Based Info Sys  11:40:00     Ratwatte
# 3        MIS 2113-910       Comp Based Info Sys  17:30:00        Berry
# 4        MIS 3013-001             C Programmimg  12:50:00       Warner
# 5        MIS 3013-002             C Programmimg  14:00:00       Warner
# 6        MIS 3033-001              Visual Basic  14:00:00     Ratwatte
# 7        MIS 3033-002                      JAVA  10:30:00      Acevedo
# 8        MIS 3033-003                      JAVA  12:50:00        Jones
# 9        MIS 3353-100                 Databases  08:10:00         Kemp
# 10       MIS 3353-001                 Databases  10:30:00       Araujo
# 11       MIS 3363-200            Infrastructure  15:10:00  Schwarzkopf
# 12       MIS 3373-200            Systems Theory  10:30:00         Kemp
# 13       MIS 4710-100             Digital Media  12:30:00     Williams
# 14       MIS 5973-200            Infrastructure  15:10:00  Schwarzkopf
# 0        MIS 2113-001       Comp Based Info Sys  09:20:00     Ferguson
# 1        MIS 2113-002       Comp Based Info Sys  10:30:00     Ferguson
# 2        MIS 2113-003       Comp Based Info Sys  11:40:00           Wu
# 3        MIS 3013-200             C Programming  12:50:00       Warner
# 4        MIS 3033-001          JAVA Programming  10:30:00     Ratwatte
# 5        MIS 3033-002  Visual Basic Programming  12:50:00     Ratwatte
# 6        MIS 3353-100                  Database  09:20:00         Kemp
# 7        MIS 3363-200            Infrastructure  15:10:00  Schwarzkopf
# 8       AH 315           32.0             35.0  Summer             3  2020
# 9       AH 315           31.0             30.0  Summer             3  2020
#
#     Monday  Tuesday  Wednesday  Thursday  Friday
# 0     True    False       True     False    True
# 1    False     True      False      True   False
# 2     True    False       True     False    True
# 3     True    False       True     False    True
# 4     True    False       True     False    True
# 5    False     True      False      True   False
# 6    False     True      False      True   False
# 7    False     True      False      True   False
# 8    False     True      False      True   False
# 9    False     True      False      True   False
# 10   False     True      False      True   False
# 11    True    False      False     False   False
# 12   False     True      False     False   False
# 13   False    False       True     False   False
# 14   False    False      False      True   False
# 15    True    False       True     False   False
# 16   False     True      False      True   False
# 17    True    False       True     False    True
# 18   False     True      False      True   False
# 19   False    False       True     False   False
# 20   False     True      False     False   False
# 21    True    False      False     False   False
# 22   False    False       True     False   False
# 23    True    False       True     False    True
# 24    True    False       True     False    True
# 25   False     True      False      True   False
# 26   False     True      False      True   False
# 27   False     True      False     False   False
# 28   False    False      False      True   False
# 29   False     True      False      True   False
# ..     ...      ...        ...       ...     ...
# 47   False     True      False     False   False
# 48    True    False      False     False   False
# 49   False    False       True     False   False
# 50   False     True      False     False   False
# 51    True    False      False     False   False
# 0    False    False       True      True    True
# 1    False    False       True      True    True
# 2     True     True       True      True    True
# 3     True     True       True      True    True
# 4     True     True       True      True    True
# 5     True     True       True      True    True
# 6     True     True       True      True    True
# 7     True     True       True      True    True
# 8     True     True       True      True    True
# 9     True     True       True      True    True
# 10    True     True       True      True    True
# 11    True     True       True      True   False
# 12    True     True       True      True    True
# 13    True     True       True      True    True
# 14    True     True       True      True   False
# 0     True     True       True      True    True
# 1     True     True       True      True    True
# 2     True     True       True      True    True
# 3     True     True       True      True    True
# 4     True     True       True      True    True
# 5     True     True       True      True    True
# 6     True     True       True      True    True
# 7     True     True       True      True   False
# 8     True     True       True      True    True
# 9     True     True       True      True   False
#
# [301 rows x 15 columns]

# %%
# asegurarse de que dentro de cada temporada los ID sean únicos
duplicates = db.groupby(['Season', 'Year'])['Course'].size().sum() - db.groupby(['Season', 'Year'])['Course'].nunique().sum()
duplicates
# Out:
# 2

# %%
# problema: hay 2 combinaciones ID-season que se repiten
db[db.duplicated(subset=['Season', 'Year', 'Course'], keep=False)]
# Out:
#           Course       Course Title     Hours Instructor    Room  \
# 50  MIS 4663-903    Systems Project  16:30:00      Price  AH 301
# 51  MIS 4663-903    Systems Project  18:30:00      Price  AH 150
# 54  MIS 4710-900      Digital Media  18:30:00   Williams  AH 312
# 55  MIS 4710-900  Advanced Database  18:30:00  Gruenwald  AH 359
#
#     Male Enrolled  Female Enrolled  Season  Season Order  Year  Monday  \
# 50           23.0             22.0  Spring             2  2019   False
# 51          180.0             99.0  Spring             2  2019    True
# 54           24.0             25.0  Spring             2  2019   False
# 55           22.0             25.0  Spring             2  2019   False
#
#     Tuesday  Wednesday  Thursday  Friday
# 50     True      False     False   False
# 51    False      False     False   False
# 54    False       True     False   False
# 55    False      False      True   False

# %% [markdown]
# #### Acá la pregunta sería cómo hacemos el join con CourseCapacity.csv teniendo en cuenta que existen estos duplicados (probablemente que 2 cursos tengan distinto título y el mismo identificador en la misma temporada es un problema de calidad de datos)

# %%
# guardamos el dataframe como un .csv pre-procesado para consumir en la task de ETL
db.to_csv(OUTPUT_PATH, encoding='utf-8')
